# %% [markdown]
# # FLIGHT PASSENGER ANALYSIS PROJECT 1

# %%
# pip installed numpy
# pip installed pandas
# pip installed matplotlib
# pip installed seaborn

# %% [markdown]
# ## IMPORT REQUIRED LIBRARIES

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### READ CSV FILES

# %%
df1=pd.read_csv(r"C:\Users\umesh\Downloads\passenger data.csv")
df1
# Out:
#             id  Gender   Customer Type  Age   Type of Travel     Class  \
# 0       114960  Female  Loyal Customer   55  Business travel  Business
# 1        43337    Male  Loyal Customer   36  Business travel       Eco
# 2        74692  Female  Loyal Customer   17  Personal Travel       Eco
# 3        98299  Female  Loyal Customer   11  Personal Travel       Eco
# 4        70039    Male  Loyal Customer   39  Business travel       Eco
# ...        ...     ...             ...  ...              ...       ...
# 122449    3154    Male  Loyal Customer   63  Personal Travel       Eco
# 122450   72489    Male  Loyal Customer   39  Business travel  Business
# 122451  104903    Male  Loyal Customer   23  Business travel  Business
# 122452  112585  Female  Loyal Customer   15  Business travel  Business
# 122453  100813  Female  Loyal Customer   17  Business travel  Business
#
#         Flight Distance
# 0                  2001
# 1                   387
# 2                  1235
# ...

# %%
df2=pd.read_csv(r"C:\Users\umesh\Downloads\survery data.csv")
df2
# Out:
#             id  Inflight wifi service  Departure/Arrival time convenient  \
# 0        70172                      3                                  4
# 1         5047                      3                                  2
# 2       110028                      2                                  2
# 3        24026                      2                                  5
# 4       119299                      3                                  3
# ...        ...                    ...                                ...
# 129875   78463                      3                                  3
# 129876   71167                      4                                  4
# 129877   37675                      2                                  5
# 129878   90086                      3                                  3
# 129879   34799                      2                                  5
#
#         Ease of Online booking  Gate location  Food and drink  \
# ...

# %% [markdown]
# ## SINCE MY PROJECT HAS TWO DIFFERENT FILES SO I HAVE MERGED BOTH OF THEM.

# %%
# using merge function by setting how='inner'
df = pd.merge(df1, df2, 
                   on='id', 
                   how='inner')
  
# displaying result
print(df)
# Out:
#             id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0       114960  Female     Loyal Customer   55  Business travel  Business
# 1       114960  Female     Loyal Customer   55  Business travel  Business
# 2        43337    Male     Loyal Customer   36  Business travel       Eco
# 3        43337    Male     Loyal Customer   36  Business travel       Eco
# 4        74692  Female     Loyal Customer   17  Personal Travel       Eco
# ...        ...     ...                ...  ...              ...       ...
# 122449    2944  Female     Loyal Customer   49  Business travel  Business
# 122450   10732    Male     Loyal Customer   33  Business travel       Eco
# 122451   22247    Male     Loyal Customer   63  Business travel  Business
# 122452  102432  Female     Loyal Customer   28  Personal Travel       Eco
# 122453   74494    Male  disloyal Customer   26  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# ...

# %% [markdown]
# # my final merged dataframes name is df.

# %%
df.shape
# Out:
# (122454, 24)

# %%
df
# Out:
#             id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0       114960  Female     Loyal Customer   55  Business travel  Business
# 1       114960  Female     Loyal Customer   55  Business travel  Business
# 2        43337    Male     Loyal Customer   36  Business travel       Eco
# 3        43337    Male     Loyal Customer   36  Business travel       Eco
# 4        74692  Female     Loyal Customer   17  Personal Travel       Eco
# ...        ...     ...                ...  ...              ...       ...
# 122449    2944  Female     Loyal Customer   49  Business travel  Business
# 122450   10732    Male     Loyal Customer   33  Business travel       Eco
# 122451   22247    Male     Loyal Customer   63  Business travel  Business
# 122452  102432  Female     Loyal Customer   28  Personal Travel       Eco
# 122453   74494    Male  disloyal Customer   26  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 122454 entries, 0 to 122453
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 122454 non-null  int64
#  1   Gender                             122454 non-null  object
#  2   Customer Type                      122454 non-null  object
#  3   Age                                122454 non-null  int64
#  4   Type of Travel                     122454 non-null  object
#  5   Class                              122454 non-null  object
#  6   Flight Distance                    122454 non-null  int64
#  7   Inflight wifi service              122454 non-null  int64
#  8   Departure/Arrival time convenient  122454 non-null  int64
#  9   Ease of Online booking             122454 non-null  int64
#  10  Gate location                      122454 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             369
# ...

# %%
# using drop to remove null values from dataframe.
df.dropna(inplace=True)

# %%
# again checked the shape of dataframe to find out that whether null values are removed or not.
df.shape
# Out:
# (122085, 24)

# %%
df.describe(include = 'all').T
# Out:
#                                       count unique                      top  \
# id                                 122085.0    NaN                      NaN
# Gender                               122085      2                   Female
# Customer Type                        122085      2           Loyal Customer
# Age                                122085.0    NaN                      NaN
# Type of Travel                       122085      2          Business travel
# Class                                122085      3                 Business
# Flight Distance                    122085.0    NaN                      NaN
# Inflight wifi service              122085.0    NaN                      NaN
# Departure/Arrival time convenient  122085.0    NaN                      NaN
# Ease of Online booking             122085.0    NaN                      NaN
# Gate location                      122085.0    NaN                      NaN
# ...

# %% [markdown]
# ### Convert the column name as title.

# %%
df.columns = df.columns.str.title()
df
# Out:
#             Id  Gender      Customer Type  Age   Type Of Travel     Class  \
# 0       114960  Female     Loyal Customer   55  Business travel  Business
# 1       114960  Female     Loyal Customer   55  Business travel  Business
# 2        43337    Male     Loyal Customer   36  Business travel       Eco
# 3        43337    Male     Loyal Customer   36  Business travel       Eco
# 4        74692  Female     Loyal Customer   17  Personal Travel       Eco
# ...        ...     ...                ...  ...              ...       ...
# 122449    2944  Female     Loyal Customer   49  Business travel  Business
# 122450   10732    Male     Loyal Customer   33  Business travel       Eco
# 122451   22247    Male     Loyal Customer   63  Business travel  Business
# 122452  102432  Female     Loyal Customer   28  Personal Travel       Eco
# 122453   74494    Male  disloyal Customer   26  Business travel  Business
#
#         Flight Distance  Inflight Wifi Service  \
# ...

# %%
df.set_index('Id', inplace=True)

# %% [markdown]
# ## In a Satisfaction column their are three values so i just replaced that values with "Yes" or "No"

# %%
df['Satisfaction'].replace({'satisfied': 'Yes', 'neutral or dissatisfied': 'No'}, inplace=True)
df
# Out:
#         Gender      Customer Type  Age   Type Of Travel     Class  \
# Id
# 114960  Female     Loyal Customer   55  Business travel  Business
# 114960  Female     Loyal Customer   55  Business travel  Business
# 43337     Male     Loyal Customer   36  Business travel       Eco
# 43337     Male     Loyal Customer   36  Business travel       Eco
# 74692   Female     Loyal Customer   17  Personal Travel       Eco
# ...        ...                ...  ...              ...       ...
# 2944    Female     Loyal Customer   49  Business travel  Business
# 10732     Male     Loyal Customer   33  Business travel       Eco
# 22247     Male     Loyal Customer   63  Business travel  Business
# 102432  Female     Loyal Customer   28  Personal Travel       Eco
# 74494     Male  disloyal Customer   26  Business travel  Business
#
#         Flight Distance  Inflight Wifi Service  \
# Id
# 114960             2001                      2
# 114960             2001                      2
# ...

# %%
df.describe(include='all').T
# Out:
#                                       count unique              top   freq  \
# Gender                               122085      2           Female  61997
# Customer Type                        122085      2   Loyal Customer  99766
# Age                                122085.0    NaN              NaN    NaN
# Type Of Travel                       122085      2  Business travel  84382
# Class                                122085      3         Business  57845
# Flight Distance                    122085.0    NaN              NaN    NaN
# Inflight Wifi Service              122085.0    NaN              NaN    NaN
# Departure/Arrival Time Convenient  122085.0    NaN              NaN    NaN
# Ease Of Online Booking             122085.0    NaN              NaN    NaN
# Gate Location                      122085.0    NaN              NaN    NaN
# Food And Drink                     122085.0    NaN              NaN    NaN
# ...

# %%
age=df['Age']
# summary statistics
print(age.describe())
# Out:
# count    122085.000000
# mean         39.404440
# std          15.115251
# min           7.000000
# 25%          27.000000
# 50%          40.000000
# 75%          51.000000
# max          85.000000
# Name: Age, dtype: float64

# %%
sns.boxplot(x=age)
plt.show()

# %%
flight_distance=df['Flight Distance']
# summary statistics
print(flight_distance.describe())
# Out:
# count    122085.000000
# mean       1179.330770
# std         995.683556
# min          31.000000
# 25%         409.000000
# 50%         837.000000
# 75%        1713.000000
# max        4983.000000
# Name: Flight Distance, dtype: float64

# %%
sns.boxplot(x=flight_distance)
plt.show()

# %%
n_df=df.copy()
n_df
# Out:
#         Gender      Customer Type  Age   Type Of Travel     Class  \
# Id
# 114960  Female     Loyal Customer   55  Business travel  Business
# 114960  Female     Loyal Customer   55  Business travel  Business
# 43337     Male     Loyal Customer   36  Business travel       Eco
# 43337     Male     Loyal Customer   36  Business travel       Eco
# 74692   Female     Loyal Customer   17  Personal Travel       Eco
# ...        ...                ...  ...              ...       ...
# 2944    Female     Loyal Customer   49  Business travel  Business
# 10732     Male     Loyal Customer   33  Business travel       Eco
# 22247     Male     Loyal Customer   63  Business travel  Business
# 102432  Female     Loyal Customer   28  Personal Travel       Eco
# 74494     Male  disloyal Customer   26  Business travel  Business
#
#         Flight Distance  Inflight Wifi Service  \
# Id
# 114960             2001                      2
# 114960             2001                      2
# ...

# %% [markdown]
# ### Removing the outliers from flight distance

# %%
n_df['Flight Distance'].describe()
# Out:
# count    122085.000000
# mean       1179.330770
# std         995.683556
# min          31.000000
# 25%         409.000000
# 50%         837.000000
# 75%        1713.000000
# max        4983.000000
# Name: Flight Distance, dtype: float64

# %%
upper_limit=n_df["Flight Distance"].mean()+ 3*n_df["Flight Distance"].std()
lower_limit=n_df["Flight Distance"].mean() - 3*n_df["Flight Distance"].std()
print("upper_limit:", upper_limit)
print("lower_limit:", lower_limit)
# Out:
# upper_limit: 4166.381438339927
# lower_limit: -1807.7198992483106

# %%
m_df = n_df.loc[(n_df["Flight Distance"] < upper_limit) & (n_df["Flight Distance"] > lower_limit)]
print("old_data:", len(n_df))
print("new_data:", len(m_df))
# Out:
# old_data: 122085
# new_data: 122007

# %%
m_df.describe(include='all').T
# Out:
#                                       count unique              top   freq  \
# Gender                               122007      2           Female  61958
# Customer Type                        122007      2   Loyal Customer  99696
# Age                                122007.0    NaN              NaN    NaN
# Type Of Travel                       122007      2  Business travel  84328
# Class                                122007      3         Business  57799
# Flight Distance                    122007.0    NaN              NaN    NaN
# Inflight Wifi Service              122007.0    NaN              NaN    NaN
# Departure/Arrival Time Convenient  122007.0    NaN              NaN    NaN
# Ease Of Online Booking             122007.0    NaN              NaN    NaN
# Gate Location                      122007.0    NaN              NaN    NaN
# Food And Drink                     122007.0    NaN              NaN    NaN
# ...

# %%
flight_distance=m_df['Flight Distance']
sns.boxplot(x=flight_distance)
# Out:
# <Axes: xlabel='Flight Distance'>

# %%
inflight_wifi_service=m_df['Inflight Wifi Service']


sns.boxplot(x=inflight_wifi_service)
# Out:
# <Axes: xlabel='Inflight Wifi Service'>

# %%
departure_arrival_time=m_df['Departure/Arrival Time Convenient']
# summary statistics

sns.boxplot(x=departure_arrival_time)
# Out:
# <Axes: xlabel='Departure/Arrival Time Convenient'>

# %%
online_booking=m_df['Ease Of Online Booking']
sns.boxplot(x=online_booking)
# Out:
# <Axes: xlabel='Ease Of Online Booking'>

# %%
gate_location=m_df['Gate Location']
sns.boxplot(x=gate_location)
# Out:
# <Axes: xlabel='Gate Location'>

# %%
food_and_drink=m_df['Food And Drink']
sns.boxplot(x=food_and_drink)
# Out:
# <Axes: xlabel='Food And Drink'>

# %%
on_boarding=m_df['Online Boarding']
sns.boxplot(x=on_boarding)
# Out:
# <Axes: xlabel='Online Boarding'>

# %%
seat_comfort=m_df['Seat Comfort']
sns.boxplot(x=seat_comfort)
# Out:
# <Axes: xlabel='Seat Comfort'>

# %%
inflight_entertainment=m_df['Inflight Entertainment']
sns.boxplot(x=inflight_entertainment)
# Out:
# <Axes: xlabel='Inflight Entertainment'>

# %%
on_board_service=m_df['On-Board Service']
sns.boxplot(x=on_board_service)
# Out:
# <Axes: xlabel='On-Board Service'>

# %%
leg_room_service=m_df['Leg Room Service']
sns.boxplot(x=leg_room_service)
# Out:
# <Axes: xlabel='Leg Room Service'>

# %%
baggage=m_df['Baggage Handling']
sns.boxplot(x=baggage)
# Out:
# <Axes: xlabel='Baggage Handling'>

# %%
checkin_service=m_df['Checkin Service']
sns.boxplot(x=checkin_service)
# Out:
# <Axes: xlabel='Checkin Service'>

# %%
inflight_service=m_df['Inflight Service']
sns.boxplot(x=inflight_service)
# Out:
# <Axes: xlabel='Inflight Service'>

# %%
cleanliness=m_df['Cleanliness']
sns.boxplot(x=cleanliness)
# Out:
# <Axes: xlabel='Cleanliness'>

# %%
dep_delay=m_df['Departure Delay In Minutes']
sns.boxplot(x=dep_delay)
# Out:
# <Axes: xlabel='Departure Delay In Minutes'>

# %%
m_df["Departure Delay In Minutes"].describe()
# Out:
# count    122007.000000
# mean         15.064693
# std          38.600241
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          13.000000
# max        1592.000000
# Name: Departure Delay In Minutes, dtype: float64

# %%
upper_limit=m_df["Departure Delay In Minutes"].mean()+ 7*m_df["Departure Delay In Minutes"].std()
lower_limit=m_df["Departure Delay In Minutes"].mean() - 7*m_df["Departure Delay In Minutes"].std()
print("upper_limit:", upper_limit)
print("lower_limit:", lower_limit)
# Out:
# upper_limit: 285.2663834762443
# lower_limit: -255.1369974574093

# %%
d_df = m_df.loc[(m_df["Departure Delay In Minutes"] < upper_limit) & (m_df["Departure Delay In Minutes"] > lower_limit)]
print("old_data:", len(m_df))
print("new_data:", len(d_df))
# Out:
# old_data: 122007
# new_data: 121651

# %%
d_df.describe(include='all').T
# Out:
#                                       count unique              top   freq  \
# Gender                               121651      2           Female  61777
# Customer Type                        121651      2   Loyal Customer  99412
# Age                                121651.0    NaN              NaN    NaN
# Type Of Travel                       121651      2  Business travel  84068
# Class                                121651      3         Business  57634
# Flight Distance                    121651.0    NaN              NaN    NaN
# Inflight Wifi Service              121651.0    NaN              NaN    NaN
# Departure/Arrival Time Convenient  121651.0    NaN              NaN    NaN
# Ease Of Online Booking             121651.0    NaN              NaN    NaN
# Gate Location                      121651.0    NaN              NaN    NaN
# Food And Drink                     121651.0    NaN              NaN    NaN
# ...

# %%
depart_delay_min=d_df['Departure Delay In Minutes']
sns.boxplot(x=depart_delay_min)
# Out:
# <Axes: xlabel='Departure Delay In Minutes'>

# %%
arrival_delay=d_df['Arrival Delay In Minutes']
sns.boxplot(x=arrival_delay)
# Out:
# <Axes: xlabel='Arrival Delay In Minutes'>

# %%
d_df["Arrival Delay In Minutes"].describe()
# Out:
# count    121651.000000
# mean         14.340556
# std          32.337147
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          13.000000
# max         422.000000
# Name: Arrival Delay In Minutes, dtype: float64

# %%
upper_limit=d_df["Arrival Delay In Minutes"].mean()+ 5*d_df["Arrival Delay In Minutes"].std()
lower_limit=d_df["Arrival Delay In Minutes"].mean() - 3*d_df["Arrival Delay In Minutes"].std()
print("upper_limit:", upper_limit)
print("lower_limit:", lower_limit)
# Out:
# upper_limit: 176.02629034905772
# lower_limit: -82.67088431950361

# %%
d_df.loc[(d_df["Arrival Delay In Minutes"] > upper_limit) | (d_df["Arrival Delay In Minutes"] < lower_limit)]
# Out:
#        Gender      Customer Type  Age   Type Of Travel     Class  \
# Id
# 13269  Female     Loyal Customer   50  Personal Travel       Eco
# 13269  Female     Loyal Customer   50  Personal Travel       Eco
# 63824  Female     Loyal Customer   49  Personal Travel  Business
# 63824  Female     Loyal Customer   49  Personal Travel  Business
# 72934    Male     Loyal Customer   46  Business travel  Business
# ...       ...                ...  ...              ...       ...
# 6990     Male     Loyal Customer   43  Business travel  Business
# 23249    Male  disloyal Customer   29  Business travel       Eco
# 35257    Male     Loyal Customer   52  Business travel  Business
# 17060  Female     Loyal Customer   21  Personal Travel       Eco
# 46737  Female     Loyal Customer   29  Personal Travel       Eco
#
#        Flight Distance  Inflight Wifi Service  \
# Id
# 13269              468                      3
# 13269              468                      3
# ...

# %%
a_df = d_df.loc[(d_df["Arrival Delay In Minutes"] < upper_limit) & (d_df["Arrival Delay In Minutes"] > lower_limit)]
print("old_data:", len(d_df))
print("new_data:", len(a_df))
# Out:
# old_data: 121651
# new_data: 120632

# %%
a_df.describe(include='all').T
# Out:
#                                       count unique              top   freq  \
# Gender                               120632      2           Female  61271
# Customer Type                        120632      2   Loyal Customer  98579
# Age                                120632.0    NaN              NaN    NaN
# Type Of Travel                       120632      2  Business travel  83362
# Class                                120632      3         Business  57180
# Flight Distance                    120632.0    NaN              NaN    NaN
# Inflight Wifi Service              120632.0    NaN              NaN    NaN
# Departure/Arrival Time Convenient  120632.0    NaN              NaN    NaN
# Ease Of Online Booking             120632.0    NaN              NaN    NaN
# Gate Location                      120632.0    NaN              NaN    NaN
# Food And Drink                     120632.0    NaN              NaN    NaN
# ...

# %%
arrival_delay_min=a_df['Arrival Delay In Minutes']
sns.boxplot(x=arrival_delay_min)
# Out:
# <Axes: xlabel='Arrival Delay In Minutes'>

# %% [markdown]
# ## Analysis of categorical column

# %%
# Gender Distribution

plt.figure(figsize= (5,5))
ax = sns.countplot(data=a_df, x="Gender")
ax.bar_label(ax.containers[0])
plt.show()

# %%
plt.figure(figsize= (5,5))
ax = sns.countplot(data=a_df, x="Type Of Travel")

plt.show()

# %% [markdown]
# ## most of the passngers are travelling through business class.

# %%
customer_type=df['Customer Type']
customer_type.value_counts().plot.bar()
plt.show()

# %%
classes=a_df['Class']
classes.value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
satisfaction=df['Satisfaction']
sns.countplot(x=satisfaction)
plt.show()

# %% [markdown]
# ## from above graph we see that the most of the passengers are not satisfied with service,etc.

# %%
sns.barplot(x=a_df['Class'], y=a_df['Seat Comfort'])
plt.show()

# %%
counts = a_df.groupby(['Gender', 'Satisfaction']).size()
print(counts)
# Out:
# Gender  Satisfaction
# Female  No              34980
#         Yes             26291
# Male    No              33267
#         Yes             26094
# dtype: int64

# %%
counts = df.groupby(['Gender', 'Satisfaction']).size().reset_index(name='count')
sns.barplot(x='Gender', y='count', hue='Satisfaction', data=counts)
plt.show()

# %% [markdown]
# ## insight-1: according to data 57% of females are not satisfied & 56% of males are not satisfied.

# %%
counts = a_df.groupby(['Class', 'Gender']).size()/a_df.shape[0]*100.0
print(counts)
# Out:
# Class     Gender
# Business  Female    23.883381
#           Male      23.516977
# Eco       Female    23.022084
#           Male      22.213011
# Eco Plus  Female     3.886199
#           Male       3.478347
# dtype: float64

# %%
counts = df.groupby(['Class', 'Gender']).size().reset_index(name='count')
sns.barplot(x='Gender', y='count', hue='Class', data=counts)
plt.show()

# %% [markdown]
# ## Insight: most of the passengers are travel through business class and Eco class.

# %%
counts = a_df.groupby(['Gender', 'Customer Type']).size()/a_df.shape[0]*100.0
print(counts)
# Out:
# Gender  Customer Type
# Female  Loyal Customer       40.928609
#         disloyal Customer     9.863055
# Male    Loyal Customer       40.790172
#         disloyal Customer     8.418164
# dtype: float64

# %%
counts = df.groupby(['Gender', 'Customer Type']).size().reset_index(name='count')
sns.barplot(x='Customer Type', y='count', hue='Gender', data=counts)
plt.show()

# %% [markdown]
# ## insight: Most of the passengers are loyal.

# %%
counts = a_df.groupby(['Class', 'Baggage Handling']).size()/a_df.shape[0]*100.0
print(counts)
# Out:
# Class     Baggage Handling
# Business  1                    2.383281
#           2                    4.439950
#           3                    7.007262
#           4                   18.390643
#           5                   15.179223
# Eco       1                    3.993965
#           2                    5.718217
#           3                   11.007859
#           4                   15.083892
#           5                    9.431163
# Eco Plus  1                    0.722031
#           2                    0.973208
#           3                    1.945587
#           4                    2.392400
#           5                    1.331322
# dtype: float64

# %%
counts = df.groupby(['Class', 'Baggage Handling']).size().reset_index(name='count')
sns.barplot(x='Class', y='count', hue='Baggage Handling', data=counts)
plt.show()

# %% [markdown]
# ## insight: baggage handling in business class is more inficient than eco class and eco plus class. So, have to improve the baggage handling in eco class and eco plus class.

# %%
counts = a_df.groupby(['Cleanliness', 'Gender']).size()/a_df.shape[0]*100.0
print(counts)
# Out:
# Cleanliness  Gender
# 0            Female     0.004974
#              Male       0.005803
# 1            Female     6.627595
#              Male       6.281915
# 2            Female     7.624842
#              Male       7.884309
# 3            Female    12.275350
#              Male      11.267325
# 4            Female    13.359639
#              Male      12.759467
# 5            Female    10.899264
#              Male      11.009517
# dtype: float64

# %%
counts = df.groupby(['Cleanliness', 'Gender']).size().reset_index(name='count')
sns.barplot(x='Cleanliness', y='count', hue='Gender', data=counts)
plt.show()

# %% [markdown]
# ## Insight: Have to improve the services like baggage handling, checkin service,etc. More you improve the services more people will travel with you.

# %%
a_df.describe(include='all').T
# Out:
#                                       count unique              top   freq  \
# Gender                               120632      2           Female  61271
# Customer Type                        120632      2   Loyal Customer  98579
# Age                                120632.0    NaN              NaN    NaN
# Type Of Travel                       120632      2  Business travel  83362
# Class                                120632      3         Business  57180
# Flight Distance                    120632.0    NaN              NaN    NaN
# Inflight Wifi Service              120632.0    NaN              NaN    NaN
# Departure/Arrival Time Convenient  120632.0    NaN              NaN    NaN
# Ease Of Online Booking             120632.0    NaN              NaN    NaN
# Gate Location                      120632.0    NaN              NaN    NaN
# Food And Drink                     120632.0    NaN              NaN    NaN
# ...

# %%
counts = a_df.groupby(['Ease Of Online Booking', 'Satisfaction']).size()/a_df.shape[0]*100.0
print(counts)
# Out:
# Ease Of Online Booking  Satisfaction
# 0                       No               1.485510
#                         Yes              2.923768
# 1                       No              10.430897
#                         Yes              6.418695
# 2                       No              16.085284
#                         Yes              7.020525
# 3                       No              16.178957
#                         Yes              7.231912
# 4                       No               8.832648
#                         Yes              9.950096
# 5                       No               3.561244
#                         Yes              9.880463
# dtype: float64

# %%
counts = a_df.groupby(['Ease Of Online Booking', 'Satisfaction']).size().reset_index(name='count')
sns.barplot(x='Satisfaction', y='count', hue='Ease Of Online Booking', data=counts)
plt.show()

# %% [markdown]
# ## Insight:most of the passengers are not satisfied with online booking.

# %%
counts = a_df.groupby(['Satisfaction', 'Gender']).size()/a_df.shape[0]*100.0
print(counts)
# Out:
# Satisfaction  Gender
# No            Female    28.997281
#               Male      27.577260
# Yes           Female    21.794383
#               Male      21.631076
# dtype: float64

# %%
counts = a_df.groupby(['Satisfaction', 'Gender']).size().reset_index(name='count')
sns.barplot(x='Satisfaction', y='count', hue='Gender', data=counts)
plt.show()

# %% [markdown]
# ## Insight:Most of the passengers are not satisfied with Services specially the female passengers.

# %%
a_df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type Of Travel', 'Class',
#        'Flight Distance', 'Inflight Wifi Service',
#        'Departure/Arrival Time Convenient', 'Ease Of Online Booking',
#        'Gate Location', 'Food And Drink', 'Online Boarding', 'Seat Comfort',
#        'Inflight Entertainment', 'On-Board Service', 'Leg Room Service',
#        'Baggage Handling', 'Checkin Service', 'Inflight Service',
#        'Cleanliness', 'Departure Delay In Minutes', 'Arrival Delay In Minutes',
#        'Satisfaction'],
#       dtype='object')

# %%
counts = a_df.groupby(['Satisfaction', 'On-Board Service']).size()/a_df.shape[0]*100.0
print(counts)
# Out:
# Satisfaction  On-Board Service
# No            0                    0.002487
#               1                    9.209828
#               2                   10.483951
#               3                   15.022548
#               4                   13.852875
#               5                    8.002852
# Yes           1                    2.290437
#               2                    3.570363
#               3                    6.960011
#               4                   15.957623
#               5                   14.647026
# dtype: float64

# %%
counts = a_df.groupby(['Satisfaction', 'On-Board Service']).size().reset_index(name='count')
sns.barplot(x='On-Board Service', y='count', hue='Satisfaction', data=counts)
plt.show()

# %%
counts = a_df.groupby(['Satisfaction', 'Inflight Service']).size()/a_df.shape[0]*100.0
print(counts)
# Out:
# Satisfaction  Inflight Service
# No            0                    0.002487
#               1                    4.792261
#               2                    7.671265
#               3                   14.819451
#               4                   19.042211
#               5                   10.246867
# Yes           1                    2.036773
#               2                    3.363121
#               3                    4.612375
#               4                   17.424067
#               5                   15.989124
# dtype: float64

# %%
counts = a_df.groupby(['Satisfaction', 'Inflight Service']).size().reset_index(name='count')
sns.barplot(x='Inflight Service', y='count', hue='Satisfaction', data=counts)
plt.show()

# %% [markdown]
# ## Insight : Most of the Passengers are not satisfied with inflight service.

# %%
plt.figure(figsize=(8, 7))
plt.subplot(121)
sns.countplot(x='Gender', data=a_df, palette='viridis')
plt.title('Gender Distribution')

plt.subplot(122)
sns.countplot(x='Customer Type', data=a_df, palette='muted')
plt.title('Customer Type Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insight: Most of the passengers are Female.
# ## Insight: Most of the passengers are likely to travelled with this fligh agency.

# %%
plt.figure(figsize=(10, 6))
plt.subplot(121)
sns.histplot(a_df['Age'], bins=20, kde=True, color='skyblue')
plt.xlabel('Age')
plt.title('Age Distribution')

plt.subplot(122)
sns.histplot(a_df['Flight Distance'], bins=20, kde=True, color='orange')
plt.xlabel('Flight Distance')
plt.title('Flight Distance Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insight : From above data we can see that the age of 25 to 45 people are travelled most and most of the passengers are prefered to travel short distance journey.

# %%
plt.figure(figsize=(10, 6))
plt.subplot(121)
sns.boxplot(y='Departure Delay In Minutes', data=a_df, color='lightgreen')
plt.ylabel('Departure Delay (Minutes)')
plt.title('Departure Delay Distribution')

plt.subplot(122)
sns.boxplot(y='Arrival Delay In Minutes', data=a_df, color='lightcoral')
plt.ylabel('Arrival Delay (Minutes)')
plt.title('Arrival Delay Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Insight: some of the flights are departure delay due long distance or weather condition or something else.

# %%
selected_cols = ['Flight Distance', 'Departure Delay In Minutes', 'Arrival Delay In Minutes', 'Age']
sns.pairplot(a_df[selected_cols], diag_kind='kde', markers='o')
plt.show()

# %% [markdown]
# ## Insight: from above data we see that younger passenger is taking shorter distance filght and elder passenger is taking longer distance flight.
#
# ## Insight: long distance flights are departure delay due to passenger condition like elder passengers are taking longer distance flight so they will take a time for boarding so it will arrive delay on their distination for this reason or it will depends on weather condition also.

# %%
corr_matrix = a_df.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\umesh\AppData\Local\Temp\ipykernel_21216\3946192089.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = a_df.corr()

# %% [markdown]
# # Insights:
#
# ##  Flight Distance vs. Departure Delay In Minutes: A positive correlation between these variables suggests that longer flight distances might be associated with longer departure delays. This could be due to longer preparation times for longer flights.
#
# ## Flight Distance vs. Arrival Delay In Minutes: Similar to the previous point, longer flight distances might be associated with longer arrival delays.
#
# ## Departure Delay In Minutes vs. Arrival Delay In Minutes: The high positive correlation between departure and arrival delays indicates that flights that experience delays during departure are likely to experience delays upon arrival as well. This could be due to various factors such as weather conditions, air traffic congestion, or operational issues.
#
# ## Age vs. Flight Distance: There is a weak positive correlation between age and flight distance. This might suggest that older passengers are slightly more likely to travel on longer flights, though the correlation is not strong.
#
# ## Age vs. Departure Delay In Minutes: There is a weak negative correlation between age and departure delays. This suggests that older passengers may experience slightly shorter departure delays, but the correlation is not significant.
#
# ## Age vs. Arrival Delay In Minutes: There is a weak negative correlation between age and arrival delays. This indicates that older passengers may experience slightly shorter arrival delays, but the correlation is not strong.

# %% [markdown]
# # Conclusion:
#
# ## We have to improve our services according to passenger requirement like Cleanliness, departure time, baggage handling, inflight service and etc.
#
# ## Target mainly on passenger who's going for business trip.
#
# ## Provide some extra offers and vouchers on online ticket booking.
